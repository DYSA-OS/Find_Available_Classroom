# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv('output.csv')
df
# Out:
#                subject professor lecture_type                time  \
# 0     (KNU10)4차산업혁명과수학     외부교원1    원격강좌(콘텐츠)                 :
# 1         (KNU10)강원문화사     외부교원1    원격강좌(콘텐츠)                 :
# 2      (KNU10)고사와성어의탐구     외부교원3    원격강좌(콘텐츠)                 :
# 3         (KNU10)과학과문화     외부교원3    원격강좌(콘텐츠)                 :
# 4      (KNU10)다문화사회의이해     외부교원2    원격강좌(콘텐츠)                 :
# ...                ...       ...          ...                 ...
# 6787            회로이론 1        허현           일반    전주:공과대학 3호관 310
# 6788             회사법 2       박수영           일반  전주:신축 법학전문대학원 102
# 6789             회사법 2       박수영           일반  전주:신축 법학전문대학원 102
# 6790            회화기법 3       서완호           일반    전주:예술대학 본관 1090
# 6791            회화실기 1       이광철           일반    전주:예술대학 본관 1191
#
#                                            room
# 0     금 10-A,금 10-B,금 11-A,금 11-B,토 10-A,토 10-B
# 1           목 1-A,목 1-B,목 2-A,목 2-B,토 2-A,토 2-B
# ...

# %%
df7 = df[df['subject'].str.contains('진로설계')]
df7
# Out:
#         subject professor lecture_type                 time         room
# 1651  대학생활과진로설계       이은지           일반         전주:간호대학 501   목 4-A,목 4-B
# 1652  대학생활과진로설계       정대업           일반     전주:공과대학 1호관 234   월 8-A,월 8-B
# 1653  대학생활과진로설계       이승희           일반     전주:공과대학 9호관 306   수 5-A,수 5-B
# 1654  대학생활과진로설계       김병석           일반     전주:공과대학 2호관 417   수 9-A,수 9-B
# 1656  대학생활과진로설계       오종현           일반     전주:공과대학 9호관 206   화 9-A,화 9-B
# ...         ...       ...          ...                  ...          ...
# 5363   전공진로설계 6       황국화           일반     전주:공과대학 2호관 201   수 0-A,수 0-B
# 5364   전공진로설계 6       양병선           일반  전주:농업생명과학대학3호관 309   월 0-A,월 0-B
# 5365   전공진로설계 6       정태종           일반       전주:글로벌인재관 205   월 0-A,월 0-B
# 5366   전공진로설계 6        명현           일반     익산:제1 환생대관 6214   화 0-A,화 0-B
# 5367   전공진로설계 6       노원엽           일반      전주:인문대학2호관 332   수 0-A,수 0-B
#
# [1394 rows x 5 columns]

# %%
df = df[df['room']!=':  ']

# %%
df= df[df['room']!='(빈칸)']

# %%
df
# Out:
#                subject professor lecture_type                time  \
# 0     (KNU10)4차산업혁명과수학     외부교원1    원격강좌(콘텐츠)                 :
# 1         (KNU10)강원문화사     외부교원1    원격강좌(콘텐츠)                 :
# 2      (KNU10)고사와성어의탐구     외부교원3    원격강좌(콘텐츠)                 :
# 3         (KNU10)과학과문화     외부교원3    원격강좌(콘텐츠)                 :
# 4      (KNU10)다문화사회의이해     외부교원2    원격강좌(콘텐츠)                 :
# ...                ...       ...          ...                 ...
# 6787            회로이론 1        허현           일반    전주:공과대학 3호관 310
# 6788             회사법 2       박수영           일반  전주:신축 법학전문대학원 102
# 6789             회사법 2       박수영           일반  전주:신축 법학전문대학원 102
# 6790            회화기법 3       서완호           일반    전주:예술대학 본관 1090
# 6791            회화실기 1       이광철           일반    전주:예술대학 본관 1191
#
#                                            room
# 0     금 10-A,금 10-B,금 11-A,금 11-B,토 10-A,토 10-B
# 1           목 1-A,목 1-B,목 2-A,목 2-B,토 2-A,토 2-B
# ...

# %% [markdown]
# ## 강의실 전처리
# 자연과학대학, 공과대학, 농업생명과학대학

# %%
college = '자연과학|공과|농업'

df1 = df[df['time'].str.contains(college)]
df1
# Out:
#                        subject professor lecture_type              time  \
# 58                   3D구조해석및실습       곽기영           일반  전주:공과대학 8호관 402
# 61                 3차원고집적반도체소자       배학열           일반  전주:공과대학 7호관 329
# 64                4차산업혁명과창의력개발       우태규           일반  전주:공과대학 8호관 212
# 74                         CAD       김태진           일반  전주:공과대학 6호관 509
# 75                      CAD및실습       육기철           일반  전주:공과대학 8호관 402
# ...                        ...       ...          ...               ...
# 6783                    회로이론 1       방준호           일반  전주:공과대학 6호관 B14
# 6784                    회로이론 1       최석우           일반  전주:공과대학 7호관 124
# 6785  회로이론 1(Circuit Theory 1)       최재호           일반  전주:공과대학 7호관 228
# 6786                    회로이론 1       정택원           일반  전주:공과대학 3호관 408
# 6787                    회로이론 1        허현           일반  전주:공과대학 3호관 310
#
#                                                  room
# 58    수 4-A,수 4-B,수 5-A,수 5-B,금 3-A,금 3-B,금 4-A,금 4-B
# ...

# %%
df1[df1['room'].str.contains('농업생명과학대학')]
# Out:
# Empty DataFrame
# Columns: [subject, professor, lecture_type, time, room]
# Index: []

# %%
len(df1)
# Out:
# 0

# %%
df1 = df1.reset_index()

# %%
df1['room'][58]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/DBprj/lib/python3.9/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 58 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1['room'][58]
#
# File ~/opt/anaconda3/envs/DBprj/lib/python3.9/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
# ...

# %%
li = []
s = []
for j in range(len(df1)):
    i = df1['room'][j]
    if '공과' in i:
        a = i.split(' ')
        b = a[0] + a[1]
        print(f'2 : {b}, {j}')
        li.append(b)
    else : #자과대, 농생대
        a = i.split(' ')
        b = a[0]
        if b =='전주:농업생명과학대학':
            s.append(j)
        print(f'1 : {b}, {j}')
        li.append(b)

li1 = set(li)

li1

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
df1.drop(s,axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df1.drop(s,axis=0, inplace=True)
#
# NameError: name 's' is not defined

# %%
df1 = df1.reset_index()

# %%
li = []
k = []
for j in range(len(df1)):
    i = df1['room'][j]
    if '공과' in i:
        a = i.split(' ')
        b = a[0] + a[1]
        if b =='전주:공과대학부속공장':
            k.append(j)
        print(f'2 : {b}, {j}')
        li.append(b)
    else : #자과대, 농생대
        a = i.split(' ')
        b = a[0]
        print(f'1 : {b}, {j}')
        li.append(b)

li1 = set(li)

li1
# Out:
# set()

# %%
k
# Out:
# []

# %%
df1.drop(k,axis=0, inplace=True)

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
# Empty DataFrame
# Columns: [level_0, index, subject, professor, lecture_type, time, room]
# Index: []

# %%
df1['building'] = 0

# %%
# building = []
for j in range(len(df1)):
    i = df1['room'][j]
    if '공과' in i:
        a = i.split(' ')
        b = a[0] + a[1]
        df1['building'][j] = b
    else : #자과대, 농생대
        c = i.split(' ')
        d = c[0]
        df1['building'][j] = d

# %%
df1.drop(['level_0', 'index'], axis=1, inplace=True)

# %%
df1
# Out:
# Empty DataFrame
# Columns: [subject, professor, lecture_type, time, room, building]
# Index: []

# %%
df1['building_room_number'] = '0'

# %%
df1.loc[df1['building'] == '전주:농업생명과학대학2호관강당', 'building_room_number'] = '100-2'

# %%
df1[df1['building']=='전주:농업생명과학대학2호관강당']['building_room_number']
# Out:
# 137     100-2
# 140     100-2
# 163     100-2
# 728     100-2
# 1126    100-2
# 2409    100-2
# Name: building_room_number, dtype: object

# %%
df1
# Out:
#                        subject professor lecture_type              room  \
# 0                    3D구조해석및실습       곽기영           일반  전주:공과대학 8호관 402
# 1                  3차원고집적반도체소자       배학열           일반  전주:공과대학 7호관 329
# 2                 4차산업혁명과창의력개발       우태규           일반  전주:공과대학 8호관 212
# 3                          CAD       김태진           일반  전주:공과대학 6호관 509
# 4                       CAD및실습       육기철           일반  전주:공과대학 8호관 402
# ...                        ...       ...          ...               ...
# 2697                    회로이론 1       방준호           일반  전주:공과대학 6호관 B14
# 2698                    회로이론 1       최석우           일반  전주:공과대학 7호관 124
# 2699  회로이론 1(Circuit Theory 1)       최재호           일반  전주:공과대학 7호관 228
# 2700                    회로이론 1       정택원           일반  전주:공과대학 3호관 408
# 2701                    회로이론 1        허현           일반  전주:공과대학 3호관 310
#
#                                                  time    building  \
# ...

# %%
for j in range(len(df1)):
    i = df1['room'][j]
    if '공과' in i:
        a = i.split(' ')
        b = a[2]
        df1['building_room_number'][j] = b
    else : #자과대, 농생대
        c = i.split(' ')
        d = c[1]
        df1['building_room_number'][j] = d
# Out:
# /var/folders/pt/xk6c0b5907z_9txgpjnm7d000000gn/T/ipykernel_36223/783534068.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1['building_room_number'][j] = b
# ...

# %%
df1
# Out:
#                        subject professor lecture_type              room  \
# 0                    3D구조해석및실습       곽기영           일반  전주:공과대학 8호관 402
# 1                  3차원고집적반도체소자       배학열           일반  전주:공과대학 7호관 329
# 2                 4차산업혁명과창의력개발       우태규           일반  전주:공과대학 8호관 212
# 3                          CAD       김태진           일반  전주:공과대학 6호관 509
# 4                       CAD및실습       육기철           일반  전주:공과대학 8호관 402
# ...                        ...       ...          ...               ...
# 2697                    회로이론 1       방준호           일반  전주:공과대학 6호관 B14
# 2698                    회로이론 1       최석우           일반  전주:공과대학 7호관 124
# 2699  회로이론 1(Circuit Theory 1)       최재호           일반  전주:공과대학 7호관 228
# 2700                    회로이론 1       정택원           일반  전주:공과대학 3호관 408
# 2701                    회로이론 1        허현           일반  전주:공과대학 3호관 310
#
#                                                  time    building  \
# ...

# %%
df2 = df1.drop('room', axis=1)

# %%
df2
# Out:
#                        subject professor lecture_type  \
# 0                    3D구조해석및실습       곽기영           일반
# 1                  3차원고집적반도체소자       배학열           일반
# 2                 4차산업혁명과창의력개발       우태규           일반
# 3                          CAD       김태진           일반
# 4                       CAD및실습       육기철           일반
# ...                        ...       ...          ...
# 2697                    회로이론 1       방준호           일반
# 2698                    회로이론 1       최석우           일반
# 2699  회로이론 1(Circuit Theory 1)       최재호           일반
# 2700                    회로이론 1       정택원           일반
# 2701                    회로이론 1        허현           일반
#
#                                                  time    building  \
# 0     수 4-A,수 4-B,수 5-A,수 5-B,금 3-A,금 3-B,금 4-A,금 4-B  전주:공과대학8호관
# 1             수 9-A,수 9-B,수 10-A,수 10-B,수 11-A,수 11-B  전주:공과대학7호관
# 2                 월 6-A,월 6-B,월 7-A,월 7-B,수 6-A,수 6-B  전주:공과대학8호관
# ...

# %% [markdown]
# ## 시간 전처리

# %%
df3 = df2
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df3 = df2
#       2 df3
#
# NameError: name 'df2' is not defined

# %%
import pandas as pd
from datetime import time

# 요일과 시간 정보 매핑
day_mapping = {
    '월': 'Monday',
    '화': 'Tuesday',
    '수': 'Wednesday',
    '목': 'Thursday',
    '금': 'Friday',
    '토': 'Saturday',
    '일': 'Sunday'
}

# 시간 블록을 파싱하여 시작 시간과 종료 시간을 반환하는 함수
def parse_time_block(block):
    time_blocks = {
        '0-A': (time(8, 0), time(8, 30)),
        '0-B': (time(8, 30), time(9, 0)),
        '1-A': (time(9, 0), time(9, 30)),
        '1-B': (time(9, 30), time(10, 0)),
        '2-A': (time(10, 0), time(10, 30)),
        '2-B': (time(10, 30), time(11, 0)),
        '3-A': (time(11, 0), time(11, 30)),
        '3-B': (time(11, 30), time(12, 0)),
        '4-A': (time(12, 0), time(12, 30)),
        '4-B': (time(12, 30), time(13, 0)),
        '5-A': (time(13, 0), time(13, 30)),
        '5-B': (time(13, 30), time(14, 0)),
        '6-A': (time(14, 0), time(14, 30)),
        '6-B': (time(14, 30), time(15, 0)),
        '7-A': (time(15, 0), time(15, 30)),
        '7-B': (time(15, 30), time(16, 0)),
        '8-A': (time(16, 0), time(16, 30)),
        '8-B': (time(16, 30), time(17, 0)),
        '9-A': (time(17, 0), time(17, 30)),
        '9-B': (time(17, 30), time(18, 0)),
        '10-A': (time(18, 0), time(18, 30)),
        '10-B': (time(18, 30), time(19, 0)),
        '11-A': (time(19, 0), time(19, 30)),
        '11-B': (time(19, 30), time(20, 0)),
        '12-A': (time(20, 0), time(20, 30)),
        '12-B': (time(20, 30), time(21, 0)),
        '13-A': (time(21, 0), time(21, 30)),
        '13-B': (time(21, 30), time(22, 0)),
        '14-A': (time(22, 0), time(22, 30)),
        '14-B': (time(22, 30), time(23, 0)),
    }
    return time_blocks[block]

# 주어진 시간 문자열을 파싱하여 요일, 시작 시간, 종료 시간 리스트를 반환하는 함수
def parse_times(time_str):
    time_entries = time_str.split(',')
    parsed_times = []

    for entry in time_entries:
        day_kor, block = entry.split()
        day_eng = day_mapping[day_kor]
        start_time, end_time = parse_time_block(block)
        parsed_times.append((day_eng, start_time, end_time))

    return parsed_times

# %%
# 새로운 컬럼을 추가할 빈 리스트 초기화
parsed_times_list = []

# 시간 문자열 파싱 및 새로운 컬럼에 데이터 추가
for index, row in df3.iterrows():
    parsed_times = parse_times(row['time'])
    parsed_times_list.append(parsed_times)

# 새로운 컬럼 추가
df3['parsed_times'] = pd.Series(parsed_times_list)

# %%
df3.drop(['day', 'start_time', 'end_time'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[218], line 1
# ----> 1 df3.drop(['day', 'start_time', 'end_time'], axis=1, inplace=True)
#
# File ~/opt/anaconda3/envs/DBprj/lib/python3.9/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
df3
# Out:
#                        subject professor lecture_type  \
# 0                    3D구조해석및실습       곽기영           일반
# 1                  3차원고집적반도체소자       배학열           일반
# 2                 4차산업혁명과창의력개발       우태규           일반
# 3                          CAD       김태진           일반
# 4                       CAD및실습       육기철           일반
# ...                        ...       ...          ...
# 2697                    회로이론 1       방준호           일반
# 2698                    회로이론 1       최석우           일반
# 2699  회로이론 1(Circuit Theory 1)       최재호           일반
# 2700                    회로이론 1       정택원           일반
# 2701                    회로이론 1        허현           일반
#
#                                                  time    building  \
# 0     수 4-A,수 4-B,수 5-A,수 5-B,금 3-A,금 3-B,금 4-A,금 4-B  전주:공과대학8호관
# 1             수 9-A,수 9-B,수 10-A,수 10-B,수 11-A,수 11-B  전주:공과대학7호관
# 2                 월 6-A,월 6-B,월 7-A,월 7-B,수 6-A,수 6-B  전주:공과대학8호관
# ...

# %%
df3.loc[df3['building']=='전주:농업생명과학대학2호관강당', 'building'] = '전주:농업생명과학대학2호관'
# df1.loc[df1['building'] == '전주:농업생명과학대학2호관강당', 'building_room_number'] = '100-2'

# %%
df3['building'].uniqe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/pt/xk6c0b5907z_9txgpjnm7d000000gn/T/ipykernel_36223/2088600813.py in ?()
# ----> 1 df3['building'].uniqe()
#
# ~/opt/anaconda3/envs/DBprj/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'uniqe'

# %%
import pandas as pd
df3 = pd.read_csv('df3.csv')

# %%
# 건물 이름과 위치(위도, 경도) 매핑
building_locations = {
    '전주:공과대학1호관': (35.846595, 127.132551),
    '전주:공과대학2호관': (35.846758, 127.131632),
    '전주:공과대학3호관': (35.846905, 127.133528),
    '전주:공과대학4호관': (35.847517, 127.132559),
    '전주:공과대학5호관': (35.847589, 127.131220),
    '전주:공과대학6호관': (35.847064, 127.134499),
    '전주:공과대학7호관': (35.846049, 127.134447),
    '전주:공과대학8호관': (35.848319, 127.133363),
    '전주:공과대학9호관': (35.847639, 127.133651),
    '전주:농업생명과학대학1호관': (35.849146, 127.130930),
    '전주:농업생명과학대학2호관': (35.849073, 127.132036),
    '전주:농업생명과학대학본관': (35.849287, 127.133276),
    '전주:농업생명과학대학3호관': (35.848656, 127.134553),
    '전주:농업생명과학대학4호관': (35.848465, 127.135489),
    '전주:자연과학대학본관': (35.847417, 127.130748),
    '전주:자연과학대학1호관': (35.845263, 127.127404),
    '전주:자연과학대학2호관': (35.845097, 127.128906),
    '전주:자연과학대학3호관': (35.847047, 127.130607),
    '전주:자연과학대학4호관': (35.846644, 127.130729),
    '전주:자연과학대학5호관': (35.846240, 127.130911)
}

# %%
# 새로운 컬럼을 추가할 빈 리스트 초기화
latitude_list = []
longitude_list = []

# 건물 이름을 기반으로 위도와 경도 값을 추가
for index, row in df3.iterrows():
    building_name = row['building']
    latitude, longitude = building_locations.get(building_name, (None, None))
    latitude_list.append(latitude)
    longitude_list.append(longitude)

# 새로운 컬럼 추가
df3['latitude'] = pd.Series(latitude_list)
df3['longitude'] = pd.Series(longitude_list)

# %% [markdown]
# # 대진설 and 전공진로설계과목 개많음 => 이건 강의실을 사용하지 않으니까 제외

# %%
df3[df3['subject'].str.contains('전공진로설계')]
# Out:
#       Unnamed: 0   subject professor lecture_type         time  \
# 1393        1393  전공진로설계 1       민상충           일반  월 0-A,월 0-B
# 1394        1394  전공진로설계 1       소승영           일반  화 0-A,화 0-B
# 1395        1395  전공진로설계 1       정대업           일반  화 0-A,화 0-B
# 1396        1396  전공진로설계 1       유기표           일반  화 0-A,화 0-B
# 1397        1397  전공진로설계 1       김윤상           일반  수 0-A,수 0-B
# ...          ...       ...       ...          ...          ...
# 2127        2127  전공진로설계 6       이태희           일반  목 0-A,목 0-B
# 2128        2128  전공진로설계 6       김대석           일반  목 0-A,목 0-B
# 2129        2129  전공진로설계 6       유효선           일반  목 0-A,목 0-B
# 2130        2130  전공진로설계 6       황국화           일반  수 0-A,수 0-B
# 2131        2131  전공진로설계 6       양병선           일반  월 0-A,월 0-B
#
#             building building_room_number  \
# 1393      전주:공과대학5호관                  506
# 1394      전주:공과대학1호관                  127
# 1395      전주:공과대학1호관                  230
# ...

# %%
df3[df3['subject'].str.contains('진로설계')]
# Out:
#       Unnamed: 0    subject professor lecture_type         time  \
# 604          604  대학생활과진로설계       정대업           일반  월 8-A,월 8-B
# 605          605  대학생활과진로설계       이승희           일반  수 5-A,수 5-B
# 606          606  대학생활과진로설계       김병석           일반  수 9-A,수 9-B
# 607          607  대학생활과진로설계       오종현           일반  화 9-A,화 9-B
# 608          608  대학생활과진로설계       김은호           일반  화 5-A,화 5-B
# ...          ...        ...       ...          ...          ...
# 2127        2127   전공진로설계 6       이태희           일반  목 0-A,목 0-B
# 2128        2128   전공진로설계 6       김대석           일반  목 0-A,목 0-B
# 2129        2129   전공진로설계 6       유효선           일반  목 0-A,목 0-B
# 2130        2130   전공진로설계 6       황국화           일반  수 0-A,수 0-B
# 2131        2131   전공진로설계 6       양병선           일반  월 0-A,월 0-B
#
#             building building_room_number  \
# 604       전주:공과대학1호관                  234
# 605       전주:공과대학9호관                  306
# 606       전주:공과대학2호관                  417
# ...

# %%
# 'subject' 컬럼에서 '전공진로설계'를 포함하는 행을 삭제
df4 = df3[~df3['subject'].str.contains('진로설계')]

df4
# Out:
#       Unnamed: 0                   subject professor lecture_type  \
# 0              0                 3D구조해석및실습       곽기영           일반
# 1              1               3차원고집적반도체소자       배학열           일반
# 2              2              4차산업혁명과창의력개발       우태규           일반
# 3              3                       CAD       김태진           일반
# 4              4                    CAD및실습       육기철           일반
# ...          ...                       ...       ...          ...
# 2697        2697                    회로이론 1       방준호           일반
# 2698        2698                    회로이론 1       최석우           일반
# 2699        2699  회로이론 1(Circuit Theory 1)       최재호           일반
# 2700        2700                    회로이론 1       정택원           일반
# 2701        2701                    회로이론 1        허현           일반
#
#                                                  time    building  \
# 0     수 4-A,수 4-B,수 5-A,수 5-B,금 3-A,금 3-B,금 4-A,금 4-B  전주:공과대학8호관
# ...

# %%
df4.to_csv('class/class/findClass/df4.csv')
